# %%
from selenium import webdriver
import selenium as se

WEBDRIVER_PATH = "/Users/songjaemin/Documents/myProjects/klue_parasite/chromedriver"

url = "http://sugang.korea.ac.kr/lecture/LecMajorSub.jsp?lang=KOR&yy=2020&tm=1R&sCampus=1&col="
scurl = "http://sugang.korea.ac.kr/lecture/LecLmtInfoWish.jsp?courcd="

xpath = lambda x, y: "/html/body/div/div[2]/form/table/tbody/tr[" + str(x) + "]/td[" + str(y) + "]"
xpath_2 = lambda x, y: "/html/body/div/table/tbody/tr[" + str(x) + "]/td[" + str(y) + "]"

# 대학 이름 및 코드 : 정보 간호 경영 공대 국제 디조 문과 미디 보과 사범 생명 의과 이과 정경 보호
camp_val = ["5720", "0231", "0140", "0217", "3928", "5338", "0143", "5256", "4669", "0234", "4652", "0226", "0209", "0197", "5436"]
camp_name = ["정보대학", "간호대학", "경영대학", "공과대학", "국제학부", "디자인조형학부", "문과대학", "미디어학부", "보건과학대학", "사범대학", "생명과학대학", "의과대학", "이과대학", "정경대학", "정보보호학부"]

# 대학별 부서
dept_val = [["6666", "5965", "5944", "5722"], ["0233"], ["0142"], ["4065", "4952", "5320", "4630", "5597", "5204", "4887", "6544", "4084"], ["3931", "5943"], ["5339"], ["4067", "5672", "6095", "6093", "4601", "0145", "0156", "0153", "0154", "0803", "0152", "0158", "0151", "4391", "0146", "6342", "6094", "5539", "0157", "0155", "0147", "6463", "0148", "0159"], ["5257"], ["4672", "5694", "5693", "4671", "5696", "5695"], ["0238", "0236", "0240", "5753", "0239", "0243", "0241", "0242", "0237", "4638"], ["4654", "4719", "4653", "4656", "5186", "6607", "4425", "5564", "4657", "5019"], ["0228", "0229"], ["0212", "0211", "0215", "0213"], ["0200", "5046", "0199", "0201", "0203"], ["5437"]]
dept_name = [["뇌인지", "소벤융", "정보보", "컴퓨터"], ["간호"], ["경영"], ["공대", "기공", "산공", "신소재", "전전", "건사환", "건축", "기창", "화생공"], ["국제", "GKS"], ["디조"], ["문과", "EML", "GLEAC", "LBC", "과기융합", "국문", "노문", "독문", "불문", "사학", "사회", "서문", "심리", "언어", "영문", "의료인문", "인문문화", "인문정의", "일문", "중문", "철학", "통일국제", "한국사", "한문"], ["미디어"], ["물리치료", "바시의", "바의공", "방사선", "보정관", "보환융"], ["가교", "교육", "국교", "다문화", "수교", "역교", "영교", "지교", "체교", "패디"], ["생공", "생과대", "생과부", "환생공", "기후변화", "미생물", "생태조경", "식공", "식자경", "의과학"], ["의예", "의학"], ["물리", "수학", "지환", "화학"], ["경제", "금융공학", "정외", "통계", "행정"], ["사국"]]

# 수강신청사이트 URL
URL = "http://sugang.korea.ac.kr/lecture/LecMajorSub.jsp?lang=KOR"
TTURL = "http://sugang.korea.ac.kr"

DRIVER_1 = webdriver.Chrome(WEBDRIVER_PATH)
DRIVER_2 = webdriver.Chrome(WEBDRIVER_PATH)

# 여기서 창 2개 뜨면 로그인 하시오
DRIVER_1.get(URL)
DRIVER_2.get(TTURL)

# %%
print(f"대학이름(번호)\t부서이름(번호)\t강좌수\t학수번호\t과목명\t교수\t1학년\t2학년\t3학년\t4학년\t교환학생\t대학원생\t전체")
for i, camp in enumerate(camp_val):
    for j, dept in enumerate(dept_val[i]):
        current_url = url + camp + "&dept=" + dept
        DRIVER_1.get(current_url)
        number_of_course = len(DRIVER_1.find_elements_by_tag_name("tr")) - 1

        for k in range(1, number_of_course + 1):
            code_ = DRIVER_1.find_element_by_xpath(xpath(k, 2)).text
            class_ = DRIVER_1.find_element_by_xpath(xpath(k, 3)).text
            
            current_url_2 = scurl + code_ + "&courcls=" + class_ + "&year=2020&term=1R"
                
            name_ = DRIVER_1.find_element_by_xpath(xpath(k, 5)).text.split('\n')[0]
            pref_ = DRIVER_1.find_element_by_xpath(xpath(k, 6)).text

            DRIVER_2.get(current_url_2)
            DRIVER_2.implicitly_wait(5)
            
            try:
                e_ = DRIVER_2.find_elements_by_xpath("/html/body/div/div[2]/span")[0].text
            except:
                e_ = "NoInfo"
                continue
            
            info_list = []
            for n in range(2, 9):
                info_list.append('/'.join((DRIVER_2.find_elements_by_xpath(xpath_2(n, 2))[0].text, DRIVER_2.find_elements_by_xpath(xpath_2(n, 3))[0].text)))
                
            print(f"{camp_name[i]}({camp})\t{dept_name[i][j]}({dept})\t{k}/{number_of_course}\t{code_}-{class_}\t{name_}\t{pref_}\t{e_}\t" + '\t'.join(info_list))
# Out:
# 대학이름(번호)	부서이름(번호)	강좌수	학수번호	과목명	교수	1학년	2학년	3학년	4학년	교환학생	대학원생	전체
# 정보대학(5720)	뇌인지(6666)	1/3	BNCS301-00	 뇌및인지과학개론(영강)	곽지현	BNCS301-00	0/-	1/-	22/-	9/-	4/5	0/-	36/35 + 5
# 정보대학(5720)	뇌인지(6666)	2/3	BNCS303-00	 뇌및의공학입문(영강)	이종환	BNCS303-00	0/-	3/-	11/-	10/-	1/5	0/-	25/35 + 5
# 정보대학(5720)	뇌인지(6666)	3/3	BNCS411-00	 뇌및머신러닝입문(영강)	감태의	BNCS411-00	0/-	0/-	4/-	9/-	0/3	0/-	13/22 + 3
# 정보대학(5720)	소벤융(5965)	1/4	STEP410-00	 현장실습V	이성권	STEP410-00	0/-	0/-	1/-	2/-	0/0	0/-	3/60 + 0
# 정보대학(5720)	소벤융(5965)	2/4	STEP411-00	 현장실습VI	이성권	STEP411-00	0/-	0/-	1/-	1/-	0/0	0/-	2/60 + 0
# 정보대학(5720)	소벤융(5965)	3/4	STEP412-00	 현장실습VII	이성권	STEP412-00	0/-	0/-	1/-	1/-	0/0	0/-	2/60 + 0
# 정보대학(5720)	소벤융(5965)	4/4	STEP413-00	 현장실습VIII	이성권	STEP413-00	0/-	0/-	1/-	1/-	0/0	0/-	2/60 + 0
# 정보대학(5720)	정보보(5944)	1/1	ISEC401-00	 고급해킹실습	김경곤	ISEC401-00	0/-	0/-	4/-	13/-	0/1	0/-	17/24 + 1
# 간호대학(0231)	간호(0233)	36/36	NRSG465-00	 지역사회간호학Ⅰ	추진아	NRSG465-00	0/-	0/-	0/-	48/-	0/0	0/-	48/75 + 0
# 경영대학(0140)	경영(0142)	1/127	BUSS003-00	 Topic Course	신명철	BUSS003-00	8/2	13/4	48/14	42/7	3/1	0/-	114/27 + 1
# 경영대학(0140)	경영(0142)	2/127	BUSS165-00	 창업가의마인드셋	김진영	BUSS165-00	0/28	12/29	28/22	23/11	2/4	0/-	65/90 + 4
# 경영대학(0140)	경영(0142)	3/127	BUSS203-01	 경영수학	박광태	BUSS203-01	0/6	5/27	10/24	2/9	0/3	0/-	17/66 + 3
# 경영대학(0140)	경영(0142)	4/127	BUSS203-02	 경영수학(영강)	이남경	BUSS203-02	8/6	46/25	47/25	20/8	1/9	0/-	122/64 + 9
# 경영대학(0140)	경영(0142)	5/127	BUSS204-00	 세계경제와기업(영강)	조경아	BUSS204-00	1/2	13/12	23/22	15/18	20/8	0/-	72/54 + 8
# 경영대학(0140)	경영(0142)	6/127	BUSS205-01	 마케팅원론	박찬수	BUSS205-01	20/20	75/50	33/16	6/4	3/4	0/-	137/90 + 4
# 경영대학(0140)	경영(0142)	7/127	BUSS205-02	 마케팅원론	김상용	BUSS205-02	7/20	39/50	13/16	3/4	2/4	0/-	64/90 + 4
# 경영대학(0140)	경영(0142)	8/127	BUSS205-03	 마케팅원론	류강석	BUSS205-03	0/20	0/50	0/16	1/4	0/4	0/-	1/90 + 4
# 경영대학(0140)	경영(0142)	9/127	BUSS205-04	 마케팅원론(영강)	유시진	BUSS205-04	1/19	1/46	4/14	1/4	14/12	0/-	21/83 + 12
# 경영대학(0140)	경영(0142)	10/127	BUSS205-05	 마케팅원론(영강)	Tony C. Garrett	BUSS205-05	2/19	1/46	1/14	1/4	12/12	0/-	17/83 + 12
# 경영대학(0140)	경영(0142)	11/127	BUSS205-06	 마케팅원론(영강)	윤성아	BUSS205-06	21/19	66/46	17/14	2/4	17/12	0/-	123/83 + 12
# 경영대학(0140)	경영(0142)	12/127	BUSS205-07	 마케팅원론(영강)	유원상	BUSS205-07	18/14	33/34	8/10	2/3	11/9	0/-	72/61 + 9
# 경영대학(0140)	경영(0142)	13/127	BUSS207-01	 재무관리(영강)	김중혁	BUSS207-01	4/8	17/39	4/16	2/6	8/10	0/-	35/69 + 10
# 경영대학(0140)	경영(0142)	14/127	BUSS207-02	 재무관리(영강)	황준호	BUSS207-02	23/9	96/46	29/20	9/8	11/12	0/-	168/83 + 12
# 경영대학(0140)	경영(0142)	15/127	BUSS207-03	 재무관리(영강)	정지웅	BUSS207-03	1/9	8/46	8/20	1/8	3/12	0/-	21/83 + 12
# 경영대학(0140)	경영(0142)	16/127	BUSS207-04	 재무관리	이웅기	BUSS207-04	6/8	47/44	28/20	4/8	3/4	0/-	88/80 + 4
# 경영대학(0140)	경영(0142)	17/127	BUSS207-05	 재무관리(영강)	SONG JUN MYUNG	BUSS207-05	15/6	58/35	19/14	5/6	4/9	0/-	101/61 + 9
# 경영대학(0140)	경영(0142)	18/127	BUSS207-06	 재무관리(영강)		BUSS207-06	3/9	10/46	4/20	0/8	1/12	0/-	18/83 + 12
# 경영대학(0140)	경영(0142)	19/127	BUSS207-07	 재무관리		BUSS207-07	2/9	9/50	5/22	2/9	0/4	0/-	18/90 + 4
# 경영대학(0140)	경영(0142)	20/127	BUSS207-08	 재무관리	황인준	BUSS207-08	1/-	2/-	17/-	15/-	0/4	0/-	35/90 + 4
# 경영대학(0140)	경영(0142)	21/127	BUSS211-01	 오퍼레이션스관리	박광태	BUSS211-01	8/10	39/54	15/20	1/6	2/4	0/-	65/90 + 4
# 경영대학(0140)	경영(0142)	22/127	BUSS211-02	 오퍼레이션스관리	김대기	BUSS211-02	1/9	13/48	6/18	0/5	2/4	0/-	22/80 + 4
# 경영대학(0140)	경영(0142)	23/127	BUSS211-03	 오퍼레이션스관리	임호순	BUSS211-03	1/7	4/40	1/15	1/4	3/3	0/-	10/66 + 3
# 경영대학(0140)	경영(0142)	24/127	BUSS211-04	 오퍼레이션스관리(영강)	신호정	BUSS211-04	30/10	93/50	21/18	4/5	16/12	0/-	164/83 + 12
# 경영대학(0140)	경영(0142)	25/127	BUSS211-05	 오퍼레이션스관리(영강)	김대수	BUSS211-05	13/9	65/45	17/16	5/4	17/11	0/-	117/74 + 11
# 경영대학(0140)	경영(0142)	26/127	BUSS211-06	 오퍼레이션스관리(영강)	김병조	BUSS211-06	0/10	26/50	4/18	1/5	8/12	0/-	39/83 + 12
# 경영대학(0140)	경영(0142)	27/127	BUSS211-07	 오퍼레이션스관리(영강)		BUSS211-07	3/10	6/50	1/18	0/5	5/12	0/-	15/83 + 12
# 경영대학(0140)	경영(0142)	28/127	BUSS213-01	 중급회계I	권수영	BUSS213-01	8/7	25/52	4/22	1/9	3/4	0/-	41/90 + 4
# 경영대학(0140)	경영(0142)	29/127	BUSS213-02	 중급회계I(영강)	최우석	BUSS213-02	14/5	63/36	20/13	6/5	3/8	0/-	106/59 + 8
# 경영대학(0140)	경영(0142)	30/127	BUSS213-03	 중급회계I(영강)	최우석	BUSS213-03	7/5	79/36	18/13	3/5	3/8	0/-	110/59 + 8
# 경영대학(0140)	경영(0142)	31/127	BUSS213-04	 중급회계I(영강)	지승민	BUSS213-04	5/7	44/49	27/19	13/8	2/12	0/-	91/83 + 12
# 경영대학(0140)	경영(0142)	32/127	BUSS213-05	 중급회계I(영강)	배진한	BUSS213-05	4/5	2/36	0/14	1/6	1/9	0/-	8/61 + 9
# 경영대학(0140)	경영(0142)	33/127	BUSS213-06	 중급회계I(영강)	유지연	BUSS213-06	15/7	93/49	26/19	7/8	0/12	0/-	141/83 + 12
# 경영대학(0140)	경영(0142)	34/127	BUSS214-01	 중급회계II	배길수	BUSS214-01	0/1	8/10	29/29	11/13	1/2	0/-	49/53 + 2
# 경영대학(0140)	경영(0142)	35/127	BUSS214-02	 중급회계II(영강)	김재영	BUSS214-02	0/1	18/14	45/41	21/18	4/11	0/-	88/74 + 11
# 경영대학(0140)	경영(0142)	36/127	BUSS215-01	 경영정보시스템	한재민	BUSS215-01	0/6	7/30	9/25	10/15	0/3	0/-	26/76 + 3
# 경영대학(0140)	경영(0142)	37/127	BUSS215-02	 경영정보시스템	정호원	BUSS215-02	5/4	17/28	4/23	8/14	0/3	0/-	34/69 + 3
# 경영대학(0140)	경영(0142)	38/127	BUSS215-03	 경영정보시스템(영강)	홍세준	BUSS215-03	10/5	58/29	38/22	21/13	6/10	0/-	133/69 + 10
# 경영대학(0140)	경영(0142)	39/127	BUSS215-04	 경영정보시스템(영강)	이재남	BUSS215-04	0/5	3/26	3/21	2/12	2/9	0/-	10/64 + 9
# 경영대학(0140)	경영(0142)	40/127	BUSS215-05	 경영정보시스템(영강)	이동원	BUSS215-05	11/6	56/34	22/27	10/16	11/12	0/-	110/83 + 12
# 경영대학(0140)	경영(0142)	41/127	BUSS215-06	 경영정보시스템(영강)	고병완	BUSS215-06	15/5	58/31	33/24	16/14	3/11	0/-	125/74 + 11
# 경영대학(0140)	경영(0142)	42/127	BUSS215-07	 경영정보시스템(영강)		BUSS215-07	0/5	1/30	3/25	1/14	0/11	0/-	5/74 + 11
# 경영대학(0140)	경영(0142)	43/127	BUSS216-00	 비즈니스애널리틱스I(영강)	김기훈	BUSS216-00	0/1	8/21	17/23	13/6	13/7	0/-	51/51 + 7
# 경영대학(0140)	경영(0142)	44/127	BUSS238-00	 광고론(영강)	서지영	BUSS238-00	1/1	28/25	50/24	24/10	26/9	0/-	129/60 + 9
# 경영대학(0140)	경영(0142)	45/127	BUSS244-01	 관리회계	김진배	BUSS244-01	1/1	20/30	28/25	6/8	2/3	0/-	57/64 + 3
# 경영대학(0140)	경영(0142)	46/127	BUSS244-02	 관리회계(영강)	유승원	BUSS244-02	2/1	38/20	68/18	26/5	7/6	0/-	141/44 + 6
# 경영대학(0140)	경영(0142)	47/127	BUSS244-03	 관리회계(영강)	한승수	BUSS244-03	0/1	14/21	24/18	10/6	6/6	0/-	54/46 + 6
# 경영대학(0140)	경영(0142)	48/127	BUSS252-01	 마케팅조사론(영강)	유시진	BUSS252-01	1/1	14/17	17/25	5/8	19/7	0/-	56/51 + 7
# 경영대학(0140)	경영(0142)	49/127	BUSS252-02	 마케팅조사론(영강)	유원상	BUSS252-02	2/1	23/18	34/27	19/8	12/8	0/-	90/54 + 8
# 경영대학(0140)	경영(0142)	50/127	BUSS254-01	 투자론(영강)	정지웅	BUSS254-01	0/1	5/16	19/34	10/12	8/9	0/-	42/63 + 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-515f4e04b02b> in <module>
#       7
#       8         for k in range(1, number_of_course + 1):
# ----> 9             code_ = DRIVER_1.find_element_by_xpath(xpath(k, 2)).text
#      10             class_ = DRIVER_1.find_element_by_xpath(xpath(k, 3)).text
#      11
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /usr/local/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# /usr/local/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
